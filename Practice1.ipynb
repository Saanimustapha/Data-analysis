# %% [markdown]
# <a href="https://colab.research.google.com/github/Saanimustapha/Data-analysis/blob/main/Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Iris1.csv')

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    7
# SepalWidthCm     6
# PetalLengthCm    7
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.head(50)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            NaN           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    2            4.9           3.0            1.4           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           NaN            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            NaN           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
mean_SL = data['SepalLengthCm'].mean()
mean_SW = data['SepalWidthCm'].mean()
mean_PL = data['PetalLengthCm'].mean()
mean_PW = data['PetalWidthCm'].mean()

# %%
mean_SL
# Out:
# 5.837062937062937

# %%
mean_SW
# Out:
# 3.047916666666667

# %%
mean_PL
# Out:
# 3.7825174825174823

# %%
mean_PW
# Out:
# 1.1966666666666668

# %%
data['SepalLengthCm'] = data['SepalLengthCm'].fillna(mean_SL)
data['SepalWidthCm'] = data['SepalWidthCm'].fillna(mean_SW)
data['PetalLengthCm'] = data['PetalLengthCm'].fillna(mean_PL)
data['PetalWidthCm'] = data['PetalWidthCm'].fillna(mean_PW)

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       5.837063      3.500000       1.400000           0.2
# 1      2       4.900000      3.000000       1.400000           0.2
# 2      2       4.900000      3.000000       1.400000           0.2
# 3      4       4.600000      3.100000       1.500000           0.2
# 4      5       5.000000      3.600000       1.400000           0.2
# ..   ...            ...           ...            ...           ...
# 145  146       6.700000      3.000000       5.200000           2.3
# 146  147       6.300000      3.047917       5.000000           1.9
# 147  148       6.500000      3.000000       5.200000           2.0
# 148  149       6.200000      3.400000       3.782517           2.3
# 149  150       5.900000      3.000000       5.100000           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
data = data.drop_duplicates()

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 3      False
# 4      False
# 5      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 146, dtype: bool

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       5.837063      3.500000       1.400000           0.2
# 1      2       4.900000      3.000000       1.400000           0.2
# 3      4       4.600000      3.100000       1.500000           0.2
# 4      5       5.000000      3.600000       1.400000           0.2
# 5      6       5.400000      3.900000       1.700000           0.4
# ..   ...            ...           ...            ...           ...
# 145  146       6.700000      3.000000       5.200000           2.3
# 146  147       6.300000      3.047917       5.000000           1.9
# 147  148       6.500000      3.000000       5.200000           2.0
# 148  149       6.200000      3.400000       3.782517           2.3
# 149  150       5.900000      3.000000       5.100000           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# ...

# %%
newData = data.filter(items=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

# %%
newData
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0         5.837063      3.500000       1.400000           0.2
# 1         4.900000      3.000000       1.400000           0.2
# 3         4.600000      3.100000       1.500000           0.2
# 4         5.000000      3.600000       1.400000           0.2
# 5         5.400000      3.900000       1.700000           0.4
# ..             ...           ...            ...           ...
# 145       6.700000      3.000000       5.200000           2.3
# 146       6.300000      3.047917       5.000000           1.9
# 147       6.500000      3.000000       5.200000           2.0
# 148       6.200000      3.400000       3.782517           2.3
# 149       5.900000      3.000000       5.100000           1.8
#
# [146 rows x 4 columns]

# %%
data.sort_values('SepalLengthCm')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 38    39            4.4           3.0            1.3           0.2
# 42    43            4.4           3.2            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 105  106            7.6           3.0            6.6           2.1
# 135  136            7.7           3.0            6.1           2.3
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 38      Iris-setosa
# 42      Iris-setosa
# 8       Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %%
corrMatrix = newData.corr()

# %%
sb.heatmap(corrMatrix,cmap='coolwarm')
# Out:
# <Axes: >

# %%
data.to_csv('Iris2.csv')
